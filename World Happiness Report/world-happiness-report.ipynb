# %%
import pandas as pd
import seaborn as sn
from matplotlib import pyplot as plt

# %% [markdown]
# First let's take a look at the report just from 2023 to see what goes into a single report, then we will later take a look at the reports made throughout the years and see how the numbers have changed over the years for some countries.

# %%
df = pd.read_csv('world-happiness-report-2023.csv')
df.shape
# Out:
# (137, 19)

# %%
df.head(10)
# Out:
#   Country name  Ladder score  Standard error of ladder score  upperwhisker  \
# 0      Finland         7.804                           0.036         7.875
# 1      Denmark         7.586                           0.041         7.667
# 2      Iceland         7.530                           0.049         7.625
# 3       Israel         7.473                           0.032         7.535
# 4  Netherlands         7.403                           0.029         7.460
# 5       Sweden         7.395                           0.037         7.468
# 6       Norway         7.315                           0.044         7.402
# 7  Switzerland         7.240                           0.043         7.324
# 8   Luxembourg         7.228                           0.069         7.363
# 9  New Zealand         7.123                           0.038         7.198
#
#    lowerwhisker  Logged GDP per capita  Social support  \
# 0         7.733                 10.792           0.969
# ...

# %%
df['Ladder score'].describe()
# Out:
# count    137.000000
# mean       5.539796
# std        1.139929
# min        1.859000
# 25%        4.724000
# 50%        5.684000
# 75%        6.334000
# max        7.804000
# Name: Ladder score, dtype: float64

# %%
sn.histplot(df['Ladder score'])

plt.show()

# %%
df[df['Country name'] == 'Serbia']
# Out:
#    Country name  Ladder score  Standard error of ladder score  upperwhisker  \
# 44       Serbia         6.144                           0.079         6.299
#
#     lowerwhisker  Logged GDP per capita  Social support  \
# 44         5.988                  9.854           0.873
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 44                   67.088                         0.845       0.204
#
#     Perceptions of corruption  Ladder score in Dystopia  \
# 44                      0.816                     1.778
#
#     Explained by: Log GDP per capita  Explained by: Social support  \
# 44                             1.552                         1.343
#
#     Explained by: Healthy life expectancy  \
# 44                                  0.424
#
#     Explained by: Freedom to make life choices  Explained by: Generosity  \
# 44                                       0.617                     0.246
#
# ...

# %% [markdown]
# Just wanted to see where Serbia ranks in the world, from now let's explore which countries are best and worst at the specific things that go into forming a final score.

# %%
df_ladder_score = df.sort_values(by='Ladder score', ascending=False)
df_ladder_score.head()
# Out:
#   Country name  Ladder score  Standard error of ladder score  upperwhisker  \
# 0      Finland         7.804                           0.036         7.875
# 1      Denmark         7.586                           0.041         7.667
# 2      Iceland         7.530                           0.049         7.625
# 3       Israel         7.473                           0.032         7.535
# 4  Netherlands         7.403                           0.029         7.460
#
#    lowerwhisker  Logged GDP per capita  Social support  \
# 0         7.733                 10.792           0.969
# 1         7.506                 10.962           0.954
# 2         7.434                 10.896           0.983
# 3         7.411                 10.639           0.943
# 4         7.346                 10.942           0.930
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                   71.150                         0.961      -0.019
# ...

# %%
df_ladder_score.tail()
# Out:
#          Country name  Ladder score  Standard error of ladder score  \
# 132  Congo (Kinshasa)         3.207                           0.095
# 133          Zimbabwe         3.204                           0.061
# 134      Sierra Leone         3.138                           0.082
# 135           Lebanon         2.392                           0.044
# 136       Afghanistan         1.859                           0.033
#
#      upperwhisker  lowerwhisker  Logged GDP per capita  Social support  \
# 132         3.394         3.020                  7.007           0.652
# 133         3.323         3.084                  7.641           0.690
# 134         3.299         2.976                  7.394           0.555
# 135         2.479         2.305                  9.478           0.530
# 136         1.923         1.795                  7.324           0.341
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# ...

# %% [markdown]
# It seems that overall Finland is ranked as the happiest country while Afghanistan is the least happy country.

# %%
df_gdp = df.sort_values(by='Logged GDP per capita', ascending=False)
df_gdp.head()
# Out:
#             Country name  Ladder score  Standard error of ladder score  \
# 8             Luxembourg         7.228                           0.069
# 24             Singapore         6.587                           0.068
# 13               Ireland         6.911                           0.044
# 7            Switzerland         7.240                           0.043
# 25  United Arab Emirates         6.571                           0.043
#
#     upperwhisker  lowerwhisker  Logged GDP per capita  Social support  \
# 8          7.363         7.093                 11.660           0.879
# 24         6.720         6.454                 11.571           0.878
# 13         6.996         6.825                 11.527           0.905
# 7          7.324         7.156                 11.164           0.920
# 25         6.656         6.486                 11.145           0.826
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# ...

# %%
df_gdp.tail()
# Out:
#          Country name  Ladder score  Standard error of ladder score  \
# 113              Chad         4.397                           0.121
# 96         Mozambique         4.954                           0.116
# 108             Niger         4.501                           0.108
# 132  Congo (Kinshasa)         3.207                           0.095
# 87          Venezuela         5.211                           0.064
#
#      upperwhisker  lowerwhisker  Logged GDP per capita  Social support  \
# 113         4.633         4.160                  7.261           0.722
# 96          5.181         4.727                  7.116           0.692
# 108         4.712         4.291                  7.091           0.590
# 132         3.394         3.020                  7.007           0.652
# 87          5.336         5.085                  5.527           0.839
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# ...

# %% [markdown]
# Luxembourg seems to be the country with the best economic production while Venezuela takes the last spot.

# %%
df_social_support = df.sort_values(by='Social support', ascending=False)
df_social_support.head()
# Out:
#    Country name  Ladder score  Standard error of ladder score  upperwhisker  \
# 2       Iceland         7.530                           0.049         7.625
# 0       Finland         7.804                           0.036         7.875
# 1       Denmark         7.586                           0.041         7.667
# 28     Slovakia         6.469                           0.056         6.578
# 17      Czechia         6.845                           0.044         6.931
#
#     lowerwhisker  Logged GDP per capita  Social support  \
# 2          7.434                 10.896           0.983
# 0          7.733                 10.792           0.969
# 1          7.506                 10.962           0.954
# 28         6.360                 10.353           0.953
# 17         6.759                 10.611           0.953
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 2                    72.050                         0.936       0.211
# ...

# %%
df_social_support.tail()
# Out:
#     Country name  Ladder score  Standard error of ladder score  upperwhisker  \
# 130       Malawi         3.495                           0.090         3.671
# 135      Lebanon         2.392                           0.044         2.479
# 129      Comoros         3.545                           0.117         3.774
# 115        Benin         4.374                           0.066         4.504
# 136  Afghanistan         1.859                           0.033         1.923
#
#      lowerwhisker  Logged GDP per capita  Social support  \
# 130         3.320                  7.302           0.531
# 135         2.305                  9.478           0.530
# 129         3.317                  8.075           0.471
# 115         4.244                  8.103           0.437
# 136         1.795                  7.324           0.341
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 130                   58.475                         0.750       0.005
# ...

# %% [markdown]
# Afghanistan takes another last spot, this time for social support. Meanwhile the first spot belongs to another top 10 country.

# %%
df_life_expectancy = df.sort_values(by='Healthy life expectancy', ascending=False)
df_life_expectancy.head()
# Out:
#                  Country name  Ladder score  Standard error of ladder score  \
# 81  Hong Kong S.A.R. of China         5.308                           0.048
# 46                      Japan         6.129                           0.042
# 24                  Singapore         6.587                           0.068
# 56                South Korea         5.951                           0.045
# 7                 Switzerland         7.240                           0.043
#
#     upperwhisker  lowerwhisker  Logged GDP per capita  Social support  \
# 81         5.403         5.214                 10.966           0.817
# 46         6.211         6.047                 10.616           0.894
# 24         6.720         6.454                 11.571           0.878
# 56         6.040         5.862                 10.693           0.812
# 7          7.324         7.156                 11.164           0.920
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# ...

# %%
df_life_expectancy.tail()
# Out:
#            Country name  Ladder score  Standard error of ladder score  \
# 90               Guinea         5.072                           0.072
# 133            Zimbabwe         3.204                           0.061
# 113                Chad         4.397                           0.121
# 96           Mozambique         4.954                           0.116
# 98   State of Palestine         4.908                           0.092
#
#      upperwhisker  lowerwhisker  Logged GDP per capita  Social support  \
# 90          5.213         4.931                  7.880           0.649
# 133         3.323         3.084                  7.641           0.690
# 113         4.633         4.160                  7.261           0.722
# 96          5.181         4.727                  7.116           0.692
# 98          5.089         4.727                  8.716           0.859
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# ...

# %% [markdown]
# Unexpectedly the country with the longest living populace isn't even close to top 10. Last place here is taken by Mozambique at 51.53 years on average.

# %%
df_freedom = df.sort_values(by='Freedom to make life choices', ascending=False)
df_freedom.head()
# Out:
#     Country name  Ladder score  Standard error of ladder score  upperwhisker  \
# 0        Finland         7.804                           0.036         7.875
# 114     Cambodia         4.393                           0.059         4.508
# 5         Sweden         7.395                           0.037         7.468
# 6         Norway         7.315                           0.044         7.402
# 41       Bahrain         6.173                           0.100         6.369
#
#      lowerwhisker  Logged GDP per capita  Social support  \
# 0           7.733                 10.792           0.969
# 114         4.279                  8.385           0.747
# 5           7.322                 10.883           0.939
# 6           7.229                 11.088           0.943
# 41          5.977                 10.776           0.844
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                     71.150                         0.961      -0.019
# ...

# %%
df_freedom.tail()
# Out:
#     Country name  Ladder score  Standard error of ladder score  upperwhisker  \
# 126   Madagascar         4.019                           0.092         4.199
# 105      Turkiye         4.614                           0.083         4.777
# 135      Lebanon         2.392                           0.044         2.479
# 129      Comoros         3.545                           0.117         3.774
# 136  Afghanistan         1.859                           0.033         1.923
#
#      lowerwhisker  Logged GDP per capita  Social support  \
# 126         3.839                  7.290           0.650
# 105         4.450                 10.307           0.796
# 135         2.305                  9.478           0.530
# 129         3.317                  8.075           0.471
# 136         1.795                  7.324           0.341
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 126                   58.050                         0.522       0.075
# ...

# %% [markdown]
# The "freest" country is Finland offering its people the highest freedom of life choices. Afghanistan again takes another last spot.

# %%
df_generosity = df.sort_values(by='Generosity', ascending=False)
df_generosity.head()
# Out:
#     Country name  Ladder score  Standard error of ladder score  upperwhisker  \
# 83     Indonesia         5.277                           0.059         5.392
# 116      Myanmar         4.372                           0.082         4.533
# 118       Gambia         4.279                           0.105         4.484
# 59      Thailand         5.843                           0.064         5.969
# 110        Kenya         4.487                           0.066         4.616
#
#      lowerwhisker  Logged GDP per capita  Social support  \
# 83          5.161                  9.385           0.804
# 116         4.212                  8.404           0.787
# 118         4.075                  7.648           0.584
# 59          5.717                  9.751           0.874
# 110         4.357                  8.458           0.690
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 83                    63.048                         0.880       0.531
# ...

# %%
df_generosity.tail()
# Out:
#     Country name  Ladder score  Standard error of ladder score  upperwhisker  \
# 131     Botswana         3.435                           0.136         3.702
# 99       Morocco         4.903                           0.061         5.023
# 46         Japan         6.129                           0.042         6.211
# 57        Greece         5.931                           0.048         6.024
# 89       Georgia         5.109                           0.056         5.219
#
#      lowerwhisker  Logged GDP per capita  Social support  \
# 131         3.168                  9.629           0.753
# 99          4.783                  8.973           0.553
# 46          6.047                 10.616           0.894
# 57          5.838                 10.288           0.835
# 89          5.000                  9.646           0.716
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 131                   54.725                         0.742      -0.215
# ...

# %% [markdown]
# The most generous people seem to be on average from Indonesia, again surprisingly another country that's not even close to the top 10. The last place here is taken by Georgia.

# %%
df_corruption = df.sort_values(by='Perceptions of corruption', ascending=False)
df_corruption.head()
# Out:
#               Country name  Ladder score  Standard error of ladder score  \
# 23                 Romania         6.589                           0.052
# 47                 Croatia         6.125                           0.057
# 70  Bosnia and Herzegovina         5.633                           0.073
# 94                 Nigeria         4.981                           0.080
# 76                Bulgaria         5.466                           0.059
#
#     upperwhisker  lowerwhisker  Logged GDP per capita  Social support  \
# 23         6.690         6.488                 10.339           0.848
# 47         6.237         6.013                 10.341           0.917
# 70         5.775         5.490                  9.616           0.880
# 94         5.136         4.825                  8.496           0.740
# 76         5.582         5.350                 10.087           0.918
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# ...

# %%
df_corruption.tail()
# Out:
#    Country name  Ladder score  Standard error of ladder score  upperwhisker  \
# 7   Switzerland         7.240                           0.043         7.324
# 5        Sweden         7.395                           0.037         7.468
# 1       Denmark         7.586                           0.041         7.667
# 0       Finland         7.804                           0.036         7.875
# 24    Singapore         6.587                           0.068         6.720
#
#     lowerwhisker  Logged GDP per capita  Social support  \
# 7          7.156                 11.164           0.920
# 5          7.322                 10.883           0.939
# 1          7.506                 10.962           0.954
# 0          7.733                 10.792           0.969
# 24         6.454                 11.571           0.878
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 7                     72.90                         0.891       0.027
# ...

# %% [markdown]
# Balkan countries like Romania, Croatia and Bosnia seem to be the countries whose citizens think the governement is the most corrupt. While on the otherhand western european countries like Switzerland, Sweden, Denmark and Finland are the least corrupt according to its citizens, but still even among those Singapore takes the first spot and by quite the margin.

# %% [markdown]
# I will not be measuring countries by their ladder score in Dystopia as they all have the same value of 1.778

# %% [markdown]
# Next I would like to take a look at how the top 10 happiest countries in 2023 have changed over the years.

# %%
df.sort_values(by='Ladder score', ascending=False, inplace=True)
df.head(10)
# Out:
#   Country name  Ladder score  Standard error of ladder score  upperwhisker  \
# 0      Finland         7.804                           0.036         7.875
# 1      Denmark         7.586                           0.041         7.667
# 2      Iceland         7.530                           0.049         7.625
# 3       Israel         7.473                           0.032         7.535
# 4  Netherlands         7.403                           0.029         7.460
# 5       Sweden         7.395                           0.037         7.468
# 6       Norway         7.315                           0.044         7.402
# 7  Switzerland         7.240                           0.043         7.324
# 8   Luxembourg         7.228                           0.069         7.363
# 9  New Zealand         7.123                           0.038         7.198
#
#    lowerwhisker  Logged GDP per capita  Social support  \
# 0         7.733                 10.792           0.969
# ...

# %%
df = pd.read_csv('world-happiness-report.csv')

# %% [markdown]
# Finland:

# %%
df_finland = df[df['Country name'] == 'Finland']
df_finland
# Out:
#     Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 551      Finland  2006        7.672              10.745           0.965
# 552      Finland  2008        7.671              10.796           0.951
# 553      Finland  2010        7.393              10.734           0.935
# 554      Finland  2011        7.354              10.754           0.938
# 555      Finland  2012        7.420              10.735           0.928
# 556      Finland  2013        7.445              10.722           0.941
# 557      Finland  2014        7.385              10.714           0.952
# 558      Finland  2015        7.448              10.716           0.948
# 559      Finland  2016        7.660              10.740           0.954
# 560      Finland  2017        7.788              10.768           0.964
# 561      Finland  2018        7.858              10.783           0.962
# 562      Finland  2019        7.780              10.792           0.937
# ...

# %%
sn.scatterplot(data=df_finland, x='year', y='Life Ladder')
plt.show()

# %% [markdown]
# Denmark:

# %%
df_denmark = df[df['Country name'] == 'Denmark']
df_denmark
# Out:
#     Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 449      Denmark  2005        8.019              10.851           0.972
# 450      Denmark  2007        7.834              10.891           0.954
# 451      Denmark  2008        7.971              10.880           0.954
# 452      Denmark  2009        7.683              10.824           0.939
# 453      Denmark  2010        7.771              10.839           0.975
# 454      Denmark  2011        7.788              10.848           0.962
# 455      Denmark  2012        7.520              10.846           0.951
# 456      Denmark  2013        7.589              10.851           0.965
# 457      Denmark  2014        7.508              10.862           0.956
# 458      Denmark  2015        7.514              10.878           0.960
# 459      Denmark  2016        7.558              10.903           0.954
# 460      Denmark  2017        7.594              10.916           0.952
# ...

# %%
sn.scatterplot(data=df_denmark, x='year', y='Life Ladder')
plt.show()

# %% [markdown]
# Iceland:

# %%
df_iceland = df[df['Country name'] == 'Iceland']
df_iceland
# Out:
#     Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 724      Iceland  2008        6.888              10.861           0.977
# 725      Iceland  2012        7.591              10.777           0.979
# 726      Iceland  2013        7.501              10.809           0.967
# 727      Iceland  2015        7.498              10.854           0.980
# 728      Iceland  2016        7.510              10.904           0.985
# 729      Iceland  2017        7.476              10.925           0.967
# 730      Iceland  2019        7.533              10.931           0.982
# 731      Iceland  2020        7.575              10.824           0.983
#
#      Healthy life expectancy at birth  Freedom to make life choices  \
# 724                             72.32                         0.885
# 725                             72.76                         0.905
# 726                             72.84                         0.923
# ...

# %%
sn.scatterplot(data=df_iceland, x='year', y='Life Ladder')
plt.show()

# %% [markdown]
# Israel:

# %%
df_israel = df[df['Country name'] == 'Israel']
df_israel
# Out:
#     Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 800       Israel  2006        7.173              10.389           0.927
# 801       Israel  2007        6.841              10.428           0.868
# 802       Israel  2008        7.261              10.440           0.859
# 803       Israel  2009        7.353              10.425           0.937
# 804       Israel  2010        7.359              10.461           0.882
# 805       Israel  2011        7.433              10.489           0.893
# 806       Israel  2012        7.111              10.493           0.903
# 807       Israel  2013        7.321              10.515           0.909
# 808       Israel  2014        7.401              10.533           0.889
# 809       Israel  2015        7.079              10.536           0.864
# 810       Israel  2016        7.159              10.555           0.890
# 811       Israel  2017        7.331              10.570           0.916
# ...

# %%
sn.scatterplot(data=df_israel, x='year', y='Life Ladder')
plt.show()

# %% [markdown]
# Netherlands:

# %%
df_netherlands = df[df['Country name'] == 'Netherlands']
df_netherlands
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 1211  Netherlands  2005        7.464              10.814           0.947
# 1212  Netherlands  2007        7.452              10.881           0.944
# 1213  Netherlands  2008        7.631              10.899           0.944
# 1214  Netherlands  2010        7.502              10.864           0.957
# 1215  Netherlands  2011        7.564              10.875           0.938
# 1216  Netherlands  2012        7.471              10.861           0.939
# 1217  Netherlands  2013        7.407              10.857           0.925
# 1218  Netherlands  2014        7.321              10.867           0.909
# 1219  Netherlands  2015        7.324              10.882           0.879
# 1220  Netherlands  2016        7.541              10.899           0.926
# 1221  Netherlands  2017        7.459              10.921           0.937
# 1222  Netherlands  2018        7.463              10.941           0.939
# ...

# %%
sn.scatterplot(data=df_netherlands, x='year', y='Life Ladder')
plt.show()

# %% [markdown]
# Sweden:

# %%
df_sweden = df[df['Country name'] == 'Sweden']
df_sweden
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 1637       Sweden  2005        7.376              10.739           0.951
# 1638       Sweden  2007        7.241              10.806           0.917
# 1639       Sweden  2008        7.516              10.793           0.923
# 1640       Sweden  2009        7.266              10.740           0.903
# 1641       Sweden  2010        7.496              10.790           0.970
# 1642       Sweden  2011        7.382              10.814           0.921
# 1643       Sweden  2012        7.560              10.800           0.929
# 1644       Sweden  2013        7.434              10.804           0.916
# 1645       Sweden  2014        7.239              10.820           0.933
# 1646       Sweden  2015        7.289              10.853           0.929
# 1647       Sweden  2016        7.369              10.861           0.912
# 1648       Sweden  2017        7.287              10.873           0.914
# ...

# %%
sn.scatterplot(data=df_sweden, x='year', y='Life Ladder')
plt.show()

# %% [markdown]
# Norway:

# %%
df_norway = df[df['Country name'] == 'Norway']
df_norway
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 1300       Norway  2006        7.416              11.031           0.959
# 1301       Norway  2008        7.632              11.042           0.936
# 1302       Norway  2012        7.678              11.017           0.948
# 1303       Norway  2014        7.444              11.024           0.941
# 1304       Norway  2015        7.603              11.033           0.947
# 1305       Norway  2016        7.596              11.035           0.960
# 1306       Norway  2017        7.579              11.050           0.950
# 1307       Norway  2018        7.444              11.056           0.966
# 1308       Norway  2019        7.442              11.061           0.942
# 1309       Norway  2020        7.290              11.042           0.956
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 1300                             71.32                         0.960
# ...

# %%
sn.scatterplot(data=df_norway, x='year', y='Life Ladder')
plt.show()

# %% [markdown]
# Switzerland:

# %%
df_switzerland = df[df['Country name'] == 'Switzerland']
df_switzerland
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 1652  Switzerland  2006        7.473              11.050           0.951
# 1653  Switzerland  2009        7.525              11.055           0.938
# 1654  Switzerland  2012        7.776              11.079           0.947
# 1655  Switzerland  2014        7.493              11.098           0.959
# 1656  Switzerland  2015        7.572              11.100           0.938
# 1657  Switzerland  2016        7.459              11.106           0.928
# 1658  Switzerland  2017        7.474              11.115           0.950
# 1659  Switzerland  2018        7.509              11.134           0.930
# 1660  Switzerland  2019        7.694              11.136           0.949
# 1661  Switzerland  2020        7.508              11.081           0.946
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 1652                             71.54                         0.919
# ...

# %%
sn.scatterplot(data=df_switzerland, x='year', y='Life Ladder')
plt.show()

# %% [markdown]
# Luxembourg:

# %%
df_luxembourg = df[df['Country name'] == 'Luxembourg']
df_luxembourg
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 1016   Luxembourg  2009        6.958              11.562           0.939
# 1017   Luxembourg  2010        7.097              11.592           0.952
# 1018   Luxembourg  2011        7.101              11.595           0.934
# 1019   Luxembourg  2012        6.964              11.567           0.914
# 1020   Luxembourg  2013        7.131              11.580           0.917
# 1021   Luxembourg  2014        6.891              11.598           0.875
# 1022   Luxembourg  2015        6.702              11.617           0.934
# 1023   Luxembourg  2016        6.967              11.640           0.941
# 1024   Luxembourg  2017        7.061              11.634           0.905
# 1025   Luxembourg  2018        7.243              11.645           0.902
# 1026   Luxembourg  2019        7.404              11.648           0.912
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
sn.scatterplot(data=df_luxembourg, x='year', y='Life Ladder')
plt.show()

# %% [markdown]
# New Zealand:

# %%
df_new_zealand = df[df['Country name'] == 'New Zealand']
df_new_zealand
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 1225  New Zealand  2006        7.305              10.526           0.946
# 1226  New Zealand  2007        7.604              10.546           0.967
# 1227  New Zealand  2008        7.381              10.528           0.944
# 1228  New Zealand  2010        7.224              10.520           0.976
# 1229  New Zealand  2011        7.191              10.536           0.954
# 1230  New Zealand  2012        7.250              10.553           0.930
# 1231  New Zealand  2013        7.280              10.571           0.958
# 1232  New Zealand  2014        7.306              10.592           0.942
# 1233  New Zealand  2015        7.418              10.608           0.987
# 1234  New Zealand  2016        7.226              10.623           0.937
# 1235  New Zealand  2017        7.327              10.633           0.955
# 1236  New Zealand  2018        7.370              10.660           0.954
# ...

# %%
sn.scatterplot(data=df_new_zealand, x='year', y='Life Ladder')
plt.show()
