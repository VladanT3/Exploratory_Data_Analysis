# %%
import pandas as pd
import seaborn as sn
from matplotlib import pyplot as plt
import numpy as np

# %%
df = pd.read_csv('students-performance.csv')
df.shape
# Out:
# (1000, 8)

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
sn.histplot(df['gender'])

plt.show()

# %%
sn.histplot(df['race/ethnicity'])

plt.show()

# %%
plt.figure(figsize=(15,6))
sn.histplot(df['parental level of education'])

plt.show()

# %%
sn.histplot(df['lunch'])

plt.show()

# %%
sn.histplot(df['test preparation course'])

plt.show()

# %%
sn.histplot(df['math score'], kde=True)

plt.show()

# %%
sn.histplot(df['reading score'], kde=True)

plt.show()

# %%
sn.histplot(df['writing score'], kde=True)

plt.show()

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df[df['test preparation course'] == 'none']['math score'].describe()
# Out:
# count    642.000000
# mean      64.077882
# std       15.192376
# min        0.000000
# 25%       54.000000
# 50%       64.000000
# 75%       74.750000
# max      100.000000
# Name: math score, dtype: float64

# %%
df[df['test preparation course'] == 'completed']['math score'].describe()
# Out:
# count    358.000000
# mean      69.695531
# std       14.444699
# min       23.000000
# 25%       60.000000
# 50%       69.000000
# 75%       79.000000
# max      100.000000
# Name: math score, dtype: float64

# %%
df[df['test preparation course'] == 'none']['reading score'].describe()
# Out:
# count    642.000000
# mean      66.534268
# std       14.463885
# min       17.000000
# 25%       57.000000
# 50%       67.000000
# 75%       76.000000
# max      100.000000
# Name: reading score, dtype: float64

# %%
df[df['test preparation course'] == 'completed']['reading score'].describe()
# Out:
# count    358.000000
# mean      73.893855
# std       13.638384
# min       37.000000
# 25%       65.000000
# 50%       75.000000
# 75%       84.000000
# max      100.000000
# Name: reading score, dtype: float64

# %%
df[df['test preparation course'] == 'none']['writing score'].describe()
# Out:
# count    642.000000
# mean      64.504673
# std       14.999661
# min       10.000000
# 25%       54.000000
# 50%       65.000000
# 75%       74.000000
# max      100.000000
# Name: writing score, dtype: float64

# %%
df[df['test preparation course'] == 'completed']['writing score'].describe()
# Out:
# count    358.000000
# mean      74.418994
# std       13.375335
# min       36.000000
# 25%       66.000000
# 50%       76.000000
# 75%       83.000000
# max      100.000000
# Name: writing score, dtype: float64

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df[df['lunch'] == 'standard']['math score'].describe()
# Out:
# count    645.000000
# mean      70.034109
# std       13.653501
# min       19.000000
# 25%       61.000000
# 50%       69.000000
# 75%       80.000000
# max      100.000000
# Name: math score, dtype: float64

# %%
df[df['lunch'] == 'free/reduced']['math score'].describe()
# Out:
# count    355.000000
# mean      58.921127
# std       15.159956
# min        0.000000
# 25%       49.000000
# 50%       60.000000
# 75%       69.000000
# max      100.000000
# Name: math score, dtype: float64

# %%
df[df['gender'] == 'male']['math score'].describe()
# Out:
# count    482.000000
# mean      68.728216
# std       14.356277
# min       27.000000
# 25%       59.000000
# 50%       69.000000
# 75%       79.000000
# max      100.000000
# Name: math score, dtype: float64

# %%
df[df['gender'] == 'female']['math score'].describe()
# Out:
# count    518.000000
# mean      63.633205
# std       15.491453
# min        0.000000
# 25%       54.000000
# 50%       65.000000
# 75%       74.000000
# max      100.000000
# Name: math score, dtype: float64

# %%
df[df['gender'] == 'male']['reading score'].describe()
# Out:
# count    482.000000
# mean      65.473029
# std       13.931832
# min       23.000000
# 25%       56.000000
# 50%       66.000000
# 75%       75.000000
# max      100.000000
# Name: reading score, dtype: float64

# %%
df[df['gender'] == 'female']['reading score'].describe()
# Out:
# count    518.000000
# mean      72.608108
# std       14.378245
# min       17.000000
# 25%       63.250000
# 50%       73.000000
# 75%       83.000000
# max      100.000000
# Name: reading score, dtype: float64

# %%
df[df['gender'] == 'male']['writing score'].describe()
# Out:
# count    482.000000
# mean      63.311203
# std       14.113832
# min       15.000000
# 25%       53.000000
# 50%       64.000000
# 75%       73.750000
# max      100.000000
# Name: writing score, dtype: float64

# %%
df[df['gender'] == 'female']['writing score'].describe()
# Out:
# count    518.000000
# mean      72.467181
# std       14.844842
# min       10.000000
# 25%       64.000000
# 50%       74.000000
# 75%       82.000000
# max      100.000000
# Name: writing score, dtype: float64
